# %% [markdown]
# # Introduction

# %% [markdown]
# Aujourd'hui la plupart des sites web utilisent du JavaScript pour rendre le site plus dynamique et agréable mais aussi pour afficher la données.
#
# Pour ces sites, la première méthode abordée n'est pas efficace, car de nombreuses requêtes sont utilisées pour se connecter, afficher la donnée, naviguer, il faudrait prendre en compte toutes ces requêtes et les assembler pour simuler le comportement du site.
#
# **C'est le comportement de votre navigateur**, il compile toutes les interactions, les requêtes et génère du HTML permettant d'afficher l'interface graphique d'un site web.
#
# Pour palier ce problème on peut laisser le navigateur faire son travail et contrôler sa surcouche logiciel. Pour cela on peut prendre le contrôle d'un navigateur comme Chrome, Edge, Firefox ou Safari depuis un script Python.
#
# Pour cela, nous allons utiliser un package Python `Selenium` https://selenium-python.readthedocs.io/ qui permet d'instancier un navigateur et de le contrôler. Sélénium est beaucoup utilisé pour générer des tests automatiques de sites web.
#
# On peut trouver les drivers des différents browser :
# - Chrome:	https://sites.google.com/a/chromium.org/chromedriver/downloads
# - Edge:	https://developer.microsoft.com/en-us/microsoft-edge/tools/webdriver/
# - Firefox:	https://github.com/mozilla/geckodriver/releases
# - Safari:	https://webkit.org/blog/6900/webdriver-support-in-safari-10/

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /Users/mmadidaroueche/opt/anaconda3/lib/python3.8/site-packages (3.141.0)
# Requirement already satisfied: urllib3 in /Users/mmadidaroueche/opt/anaconda3/lib/python3.8/site-packages (from selenium) (1.25.9)

# %%
from selenium import webdriver

# %%
IS_LINUX = False

# %%
chrome = webdriver.Chrome(executable_path="./chromedriver" if not IS_LINUX else "./chromedriver_linux")

# %% [markdown]
# Vous devez voir apparaître une nouvelle instance de votre navigateur. Si vous voulez accéder à une page :

# %%
chrome.get("https://www.senscritique.com/top/resultats/Les_meilleurs_films_de_2020/2582670")

# %% [markdown]
# Allez maintenant voir votre fenêtre. Vous êtes sur le site d'amazon. Vous pouvez maintenant vous déplacer dans la page. Pour cela il va falloir inspecter le code source de la page.
#
# Il existe de nombreuse méthode pour récupérer les éléments par exemple `find_element_by_link_text` qui permet de récupérer un élément grâce au text affiché. Ici, si on veut récupérer toutes les `Ventes Flash`

# %%
chrome.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#link = chrome.find_element_by_link_text("Voir tout")
#type(link)

# %% [markdown]
# Si on veut entrer dans le lien, il suffit d'appeler la méthode `click`.

# %%
link.click()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5463b5cdf4d5> in <module>
# ----> 1 link.click()
#
# NameError: name 'link' is not defined

# %% [markdown]
# Vous êtes arrivé sur la page des ventes flash. Maintenant nous allons récupérer toutes les ventes actuelles. On remarque que les ventes sont stockés dans des widgets qui porte l'id `widgetContent`.

# %%
all_widgets = chrome.find_elements_by_class_name("d-rubric")
type(all_widgets), len(all_widgets)
# Out:
# (list, 6)

# %% [markdown]
# On obtient une liste d'éléments décrits par cet identifiant. Il y en a 5, un pour chaque ligne. Pour récupérer les différentes offres de la première ligne. on récupère les sections correspondantes:

# %%
first_line = all_widgets[0]
all_first_line_elements = first_line.find_elements_by_class_name('elpo-item')
len(all_first_line_elements)

# %% [markdown]
# Pour récupérer le text maintenant :

# %%
# Aussi présent dans :
# Les meilleurs films français de 2020
# Les meilleurs films belges
# Les films les plus attendus de 2020
#
# 58
# Effacer l'historique (2020)
# Film de Benoît Delépine et Gustave Kervern avec Blanche Gardin, Denis Podalydès, Corinne Masiero
# Aussi présent dans :
# Les meilleurs films du duo Gustave Kervern et Benoît Delépine
# Les meilleurs films français de 2020
# Les meilleurs films sur l'informatique
# Les meilleurs films avec Gustave Kervern
#
# 59
# Balle perdue (2020)
# Film de Guillaume Pierret avec Alban Lenoir, Nicolas Duvauchelle, Ramzy Bédia
# Aussi présent dans :
# Les meilleurs films français de 2020
# Les meilleurs films avec Nicolas Duvauchelle
# Les meilleurs films avec Alban Lenoir
#
# 60
# Dans un jardin qu'on dirait éternel (2020)
# Nichinichi Kore Kôjitsu
# Film de Tatsushi Omori avec Kirin Kiki, Haru Kuroki, Mikako Tabe
#
# 61
# Kajillionaire (2020)
# Film de Miranda July avec Evan Rachel Wood, Gina Rodriguez, Richard Jenkins
# Aussi présent dans :
# Les meilleurs films avec Evan Rachel Wood
#
# 62
# L'Appel de la forêt (2020)
# The Call of the Wild
# Film de Chris Sanders avec Harrison Ford, Dan Stevens, Omar Sy
# Aussi présent dans :
# Les meilleurs films où le personnage principal est un chien
# Les films les plus attendus de 2020
# Les meilleurs films avec Dan Stevens
# Les meilleurs films avec Omar Sy
#
# 63
# Mignonnes (2020)
# Film de Maïmouna Doucouré avec Fathia Youssouf, Medina El Aidi, Esther Gohourou
# Aussi présent dans :
# Les meilleurs films français de 2020
# Les meilleurs films sur la danse
#
# 64
# Palm Springs (2021)
# Film de Max Barbakow avec Andy Samberg, Cristin Milioti, Peter Gallagher
# Aussi présent dans :
# Les meilleurs films avec Andy Samberg
#
# 65
# Enola Holmes (2020)
# Film de Harry Bradbeer avec Millie Bobby Brown, Henry Cavill, Sam Claflin
# Aussi présent dans :
# Les meilleurs Sherlock Holmes
# Les meilleurs films avec Henry Cavill
# Les meilleurs films avec Sam Claflin
# 66
# Sonic, le film (2020)
# Sonic the Hedgehog
# Film de Jeff Fowler avec Ben Schwartz, Malik Bentalha, Jim Carrey
# Aussi présent dans :
# Les meilleurs films adaptés d'un jeu vidéo
# Les meilleurs films mêlant animation et prises de vue réelles
# Les films les plus attendus de 2020
#
# 67
# Hotel by the River (2020)
# Gangbyun Hotel
# Film de Hong Sang-soo avec Ki Joo-bong, Kim Min-hee, Song Seon-Mi
#
# 68
# La Femme qui s’est enfuie (2020)
# Domangchin yeoja
# Film de Hong Sang-soo avec Kim Min-hee, Seo Young-hwa, Song Seon-Mi
# Aussi présent dans :
# Les meilleurs films de Hong Sang-soo
#
# 69
# La Cravate (2020)
# Documentaire de Mathias Théry et Etienne Chaillou
# Aussi présent dans :
# Les meilleurs films français de 2020
#
# 70
# Bad Boys for Life (2020)
# Film de Adil El Arbi et Bilall Fallah avec Will Smith, Martin Lawrence, Joe Pantoliano
# Aussi présent dans :
# Les films les plus attendus de 2020
# Les meil
# Aussi présent dans :
# Les meilleurs films où le personnage principal est un chien
#
# 86
# Pinocchio (2020)
# Film de Matteo Garrone avec Roberto Benigni, Federico Ielapi, Rocco Papaleo
# Aussi présent dans :
# Les films les plus attendus de 2020
# Les meilleurs films sur le cirque
# Les meilleurs films avec Roberto Benigni
#
# 87
# Deux (2020)
# Film de Filippo Meneghetti avec Barbara Sukowa, Martine Chevallier, Léa Drucker
# Aussi présent dans :
# Les meilleurs films français de 2020
#
# 88
# Antebellum (2020)
# Film de Gerard Bush et Christopher Renz avec Janelle Monáe, Jena Malone, Kiersey Clemons
# Aussi présent dans :
# Les meilleurs films sur l'esclavage
#
# 89
# The Old Guard (2020)
# Film de Gina Prince-Bythewood avec Charlize Theron, Marwan Kenzari, Harry Melling
# Aussi présent dans :
# Les meilleurs films sur l'immortalité
# Les meilleurs films avec Chiwetel Ejiofor
#
# 90
# Eurovision Song Contest: The Story of Fire Saga (2020)
# Film de David Dobkin avec Will Ferrell, Rachel McAdams, Dan Stevens
# Aussi présent dans :
# Les meilleurs films avec Dan Stevens
# Les meilleurs films avec Pierce Brosnan
# Les meilleurs films avec Rachel McAdams
#
# 91
# Da 5 Bloods : Frères de sang (2020)
# Da 5 Bloods
# Film de Spike Lee avec Chadwick Boseman, Jean Reno, Paul Walter Hauser
# Aussi présent dans :
# Les meilleurs films de Spike Lee
#
# 92
# Calamity, une enfance de Martha Jane Cannary (2020)
# Long-métrage d'animation de Rémi Chayé avec Salomé Boulven, Alexandra Lamy, Alexis Tomassian
# Aussi présent dans :
# Les meilleurs films français de 2020
#
# 93
# Malmkrog (2020)
# Film de Cristi Puiu avec Frédéric Schulz-Richard, Diana Sakalauskaite, Ugo Broussot
#
# 94
# Kubrick par Kubrick (2020)
# Documentaire de Grégory Monro avec Stanley Kubrick, Michel Ciment, Malcolm McDowell
# Aussi présent dans :
# Les meilleurs documentaires sur le cinéma
# Les meilleurs films français de 2020
#
# 95
# The Lodge (2020)
# Film de Severin Fiala et Veronika Franz avec Richard Armitage, Riley Keough, Alicia Silverstone
# Aussi présent dans :
# Les meilleurs films de la Hammer
# Les meilleurs films de « home invasion »
#
# 96
# La Llorona (2020)
# Film de Jayro Bustamante avec María Mercedes Coroy, Sabrina De La Hoz, Julio Díaz
# Aussi présent dans :
# Les meilleurs films latino-américains
#
# 97
# Family Romance, LLC (2020)
# Film de Werner Herzog avec Yuichi Ishii, Mahiro Tanimoto, Miki Fujimaki
#
# 98
# Emma. (2020)
# Film de Autumn de Wilde avec Anya Taylor-Joy, Angus Imrie, Letty Thomas
#
# 99
# Blackbird (2020)
# Film de Roger Michell avec Kate Winslet, Susan Sarandon, Rainn Wilson
# Aussi présent dans :
# Les meilleurs films avec Mia Wasikowska
#
# 100
# Le Cri du faucon (2020)
# The Peanut Butter Falcon
# Film de Tyler Nilson et Michael Schwartz avec Zachary Gottsagen, Shia LaBeouf, Dakota Johnson
# Aussi présent dans :
# Les meilleurs films traitant du handicap
# Les meilleurs films avec Shia Labeouf

# %% [markdown]
# Si vous êtes fan de JavaScript vous pouvez même injecter du code JS dans le navigateur depuis Python pour exécuter des opérations complexes.

# %%
js_script = """
const class_name = 'DRIOC'
console.log(`Hi from ${class_name}`)
"""

# %%
chrome.execute_script(js_script)

# %% [markdown]
# Vous pouvez aller vérifier dans la console Javascript du navigateur que le message apparait bien.

# %% [markdown]
# # Exercice

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# Extraire le prix des offres :

# %%
def extract_price(offer_web_element): 
    alli = offer_web_element.find_elements_by_class_name("elco-anchor")
    return alli[0].text
#ou 
def extract_price2(offer_web_element):
    lst_prix = []
    l = offer_web_element.text
    l = l.split("\n")
    for elt in l:
        for i in elt:
            if i =="€":
                return elt
    return None
    #raise NotImplementedError('Need to be implemented')
    #pass
lst =  []
for i in range(len(all_first_line_elements)):
    lst.append(extract_price(all_first_line_elements[i]))
#print(all_first_line_elements[19].text)

# %%
len(lst)
dico = []
# Out:
# 100

# %%
link = chrome.find_element_by_link_text('1917')
link.click()

# %%
element = chrome.find_element_by_tag_name("h3")

# %%
durée = chrome.find_element_by_tag_name("time")
durée.text
# Out:
# '15 janvier 2020'

# %%
actors = (chrome.find_elements_by_class_name("d-rubric"))[0].find_elements_by_class_name('d-offset.ecot-contact-label')
actor = []
for i in range(len(actors)):
    actor.append((actors[i].text))
# Out:
# ['George MacKay',
#  'Dean-Charles Chapman',
#  'Benedict Cumberbatch',
#  'Colin Firth',
#  'Mark Strong']

# %%
link = chrome.find_element_by_link_text('1917')
link.click()

element = chrome.find_element_by_tag_name("h3")

durée = chrome.find_element_by_tag_name("time")
durée.text

actors = (chrome.find_elements_by_class_name("d-rubric"))[0].find_elements_by_class_name('d-offset.ecot-contact-label')
actor = []
for i in range(len(actors)):
    actor.append((actors[i].text))
    
direct = chrome.find_element_by_xpath("/html/body/div[3]/div[2]/div[3]/div/section[1]/ul/li[1]/span")
direct.text
# Out:
# 'Sam Mendes'

# %% [markdown]
# Extraire l'image de l'offre:

# %%
def extract_image(offer_web_element):
    alli = [ image.get_attribute("src") for image in offer_web_element.find_elements_by_tag_name("img")]
    return alli
    
extract_image(all_first_line_elements[0])
# Out:
# ['https://m.media-amazon.com/images/G/08/_tools/1200_Brands_Generic/FR_DOTD._AA210_.png']

# %% [markdown]
# Extraire le titre de l'offre:

# %%
def extract_title(offer_web_element):
    alli = offer_web_element.find_elements_by_class_name("d-heading4 elpt-product-title size160")
    return alli[0].text

extract_title(all_first_line_elements[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-70c66cf95dc8> in <module>
#       3     return alli[0].text
#       4
# ----> 5 extract_title(all_first_line_elements[0])
#
# <ipython-input-53-70c66cf95dc8> in extract_title(offer_web_element)
#       1 def extract_title(offer_web_element):
#       2     alli = offer_web_element.find_elements_by_class_name("d-heading4 elpt-product-title size160")
# ----> 3     return alli[0].text
#       4
#       5 extract_title(all_first_line_elements[0])
#
# IndexError: list index out of range

# %%
chrome.close()
